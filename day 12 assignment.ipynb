# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

ds=pd.read_csv('general_data.csv')

# %%
from sklearn import preprocessing
Label_encoder=preprocessing.LabelBinarizer()
ds['Attrition']=Label_encoder.fit_transform(ds['Attrition'])

# %%
ds.head()
# Out:
#    Age  Attrition     BusinessTravel              Department  \
# 0   51          0      Travel_Rarely                   Sales
# 1   31          1  Travel_Frequently  Research & Development
# 2   32          0  Travel_Frequently  Research & Development
# 3   38          0         Non-Travel  Research & Development
# 4   32          0      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                 6          2  Life Sciences              1           1
# 1                10          1  Life Sciences              1           2
# 2                17          4          Other              1           3
# 3                 2          5  Life Sciences              1           4
# 4                10          1        Medical              1           5
#
#    Gender  ...  NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# 0  Female  ...                 1.0      Y                11              8
# ...

# %% [markdown]
# # Wilcoxon Test

# %%
from scipy.stats import wilcoxon
stats,p=wilcoxon(ds.JobLevel,ds.Education)
print(stats,p)
# Out:
# 1146648.0 8.724635739045322e-236

# %%
8.724635739045322e-2
# Out:
# 0.08724635739045322

# %% [raw]
# stats is 1146648 p value is 0.08 ,p>0.05 ,H0 is accepted and H1 is rejected

# %%
ds1=ds.dropna()

# %%
ds
# Out:
#       Age  Attrition     BusinessTravel              Department  \
# 0      51          0      Travel_Rarely                   Sales
# 1      31          1  Travel_Frequently  Research & Development
# 2      32          0  Travel_Frequently  Research & Development
# 3      38          0         Non-Travel  Research & Development
# 4      32          0      Travel_Rarely  Research & Development
# 5      46          0      Travel_Rarely  Research & Development
# 6      28          1      Travel_Rarely  Research & Development
# 7      29          0      Travel_Rarely  Research & Development
# 8      31          0      Travel_Rarely  Research & Development
# 9      25          0         Non-Travel  Research & Development
# 10     45          0      Travel_Rarely  Research & Development
# 11     36          0      Travel_Rarely  Research & Development
# 12     55          0      Travel_Rarely  Research & Development
# 13     47          1         Non-Travel  Research & Development
# ...

# %%
from scipy.stats import friedmanchisquare
stats,p=friedmanchisquare(ds.StandardHours,ds.StockOptionLevel,ds.TotalWorkingYears)
print(stats,p)
# Out:
# 6482.700505843364 0.0

# %% [markdown]
# # Mannwhiteneyu Test

# %% [raw]
# Mannwhiteneyu Test is to compare between 2 independent samples.

# %%
from scipy.stats import mannwhitneyu
stats,p=mannwhitneyu(ds.DistanceFromHome,ds.Education)
print(stats,p)
# Out:
# 5503365.0 2.371790832392393e-279

# %%
2.371790832392393e-02
# Out:
# 0.02371790832392393

# %% [markdown]
# R_value is 550336 and P_value is 0.023

# %% [markdown]
# 0.023<0.05 so null value is Rejected and Alternate value is accepted.

# %% [markdown]
# H0- There is no significant difference distance from and education

# %%
from scipy.stats import ttest_1samp
stats,p=ttest_1samp(ds.JobLevel,76)
print(stats,p)
# Out:
# -4436.597683853069 0.0

# %% [markdown]
# # Two Sample Paired T-test

# %%
from scipy.stats import ttest_rel
stats,p=ttest_rel(ds.JobLevel,ds.Education)
print(stats,p)
# Out:
# -38.27670663139589 4.972071747597808e-277

# %%
4.972071747597808e-2
# Out:
# 0.04972071747597808

# %% [raw]
# r_value is -38.27 which is negative correlation and P_value is 0.04 <0.05 so H0 is rejected

# %%
from sklearn import preprocessing
Label_encoder=preprocessing.LabelEncoder()
ds['Gender']=Label_encoder.fit_transform(ds['Gender'])
ds['MaritalStatus']=Label_encoder.fit_transform(ds['MaritalStatus'])

# %%
ds.head()
# Out:
#    Age  Attrition     BusinessTravel              Department  \
# 0   51          0      Travel_Rarely                   Sales
# 1   31          1  Travel_Frequently  Research & Development
# 2   32          0  Travel_Frequently  Research & Development
# 3   38          0         Non-Travel  Research & Development
# 4   32          0      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                 6          2  Life Sciences              1           1
# 1                10          1  Life Sciences              1           2
# 2                17          4          Other              1           3
# 3                 2          5  Life Sciences              1           4
# 4                10          1        Medical              1           5
#
#    Gender  ...  NumCompaniesWorked Over18  PercentSalaryHike  StandardHours  \
# 0       0  ...                 1.0      Y                 11              8
# ...

# %% [markdown]
# # Chi square Test

# %%
from scipy.stats import chi2_contingency


chitable = pd.crosstab(ds.Gender, ds.MaritalStatus)
stats, p, dof, expected = chi2_contingency(chitable)
print(stats,p)
# Out:
# 6.428867202141822 0.04017808420398627

# %% [raw]
#   stats value is 6.42 ,p value is 0.04 , p<0.05 so H0 is rejected and H1 is accepted

# %%
ds
# Out:
#       Age  Attrition     BusinessTravel              Department  \
# 0      51          0      Travel_Rarely                   Sales
# 1      31          1  Travel_Frequently  Research & Development
# 2      32          0  Travel_Frequently  Research & Development
# 3      38          0         Non-Travel  Research & Development
# 4      32          0      Travel_Rarely  Research & Development
# 5      46          0      Travel_Rarely  Research & Development
# 6      28          1      Travel_Rarely  Research & Development
# 7      29          0      Travel_Rarely  Research & Development
# 8      31          0      Travel_Rarely  Research & Development
# 9      25          0         Non-Travel  Research & Development
# 10     45          0      Travel_Rarely  Research & Development
# 11     36          0      Travel_Rarely  Research & Development
# 12     55          0      Travel_Rarely  Research & Development
# 13     47          1         Non-Travel  Research & Development
# ...

# %% [markdown]
# # Kruskal Test

# %%
from scipy.stats import kruskal
stats,p=kruskal(ds.YearsSinceLastPromotion,ds.StockOptionLevel,ds.PercentSalaryHike)
print(stats,p)
# Out:
# 8977.05276652898 0.0

# %% [raw]
# It is normally distributed.
