# %% [markdown]
# Performing Correlation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

dataset=pd.read_csv('general_data.csv')

# %% [raw]
# converting a categorical into numerical value

# %%
dataset["Attrition"].replace(to_replace=("No","Yes"),value=(0,1),inplace=True)

# %% [markdown]
# Correlation Between Attrition and MonthlyIncome

# %%
from scipy.stats import pearsonr
stats,p=pearsonr(dataset.Attrition,dataset.MonthlyIncome)
print(stats,p)
# Out:
# -0.031176281698115017 0.038427484905971684

# %% [raw]
# r=-0.0311 and P_value is 0.03

# %%
dataset.corr()
# Out:
#                               Age  Attrition  DistanceFromHome  Education  \
# Age                      1.000000  -0.159205          0.006963  -0.035706
# Attrition               -0.159205   1.000000         -0.009730  -0.015111
# DistanceFromHome         0.006963  -0.009730          1.000000  -0.008638
# Education               -0.035706  -0.015111         -0.008638   1.000000
# EmployeeCount                 NaN        NaN               NaN        NaN
# EmployeeID               0.008649  -0.004729         -0.001097  -0.009680
# JobLevel                -0.002884  -0.010290         -0.037329   0.045746
# MonthlyIncome           -0.044314  -0.031176         -0.021607   0.006410
# NumCompaniesWorked       0.299243   0.042345         -0.013843  -0.016250
# PercentSalaryHike       -0.033137   0.032533          0.038125  -0.040531
# StandardHours                 NaN        NaN               NaN        NaN
# StockOptionLevel        -0.031753  -0.006839          0.011169   0.001261
# ...

# %% [raw]
# Correlation:Negative Correlation
# p_value<0.05,so H0 is Rejected

# %%
stats,p=pearsonr(dataset.Attrition,dataset.DistanceFromHome)
print(stats,p)
# Out:
# -0.009730141010179659 0.5182860428065224

# %%
dataset.corr()
# Out:
#                               Age  Attrition  DistanceFromHome  Education  \
# Age                      1.000000  -0.159205          0.006963  -0.035706
# Attrition               -0.159205   1.000000         -0.009730  -0.015111
# DistanceFromHome         0.006963  -0.009730          1.000000  -0.008638
# Education               -0.035706  -0.015111         -0.008638   1.000000
# EmployeeCount                 NaN        NaN               NaN        NaN
# EmployeeID               0.008649  -0.004729         -0.001097  -0.009680
# JobLevel                -0.002884  -0.010290         -0.037329   0.045746
# MonthlyIncome           -0.044314  -0.031176         -0.021607   0.006410
# NumCompaniesWorked       0.299243   0.042345         -0.013843  -0.016250
# PercentSalaryHike       -0.033137   0.032533          0.038125  -0.040531
# StandardHours                 NaN        NaN               NaN        NaN
# StockOptionLevel        -0.031753  -0.006839          0.011169   0.001261
# ...

# %% [markdown]
# Correlation between Attrition and Education

# %%
stats,p=pearsonr(dataset.Attrition,dataset.Education)
print(stats,p)
# Out:
# -0.015111167710968744 0.3157293177115451

# %% [raw]
# r_value=-0.015 and p_value is 0.315

# %% [raw]
# Correlation:Negative Correlation
# p_value>0.05,so H0 is Accepted

# %%
dataset.corr()
# Out:
#                               Age  Attrition  DistanceFromHome  Education  \
# Age                      1.000000  -0.159205          0.006963  -0.035706
# Attrition               -0.159205   1.000000         -0.009730  -0.015111
# DistanceFromHome         0.006963  -0.009730          1.000000  -0.008638
# Education               -0.035706  -0.015111         -0.008638   1.000000
# EmployeeCount                 NaN        NaN               NaN        NaN
# EmployeeID               0.008649  -0.004729         -0.001097  -0.009680
# JobLevel                -0.002884  -0.010290         -0.037329   0.045746
# MonthlyIncome           -0.044314  -0.031176         -0.021607   0.006410
# NumCompaniesWorked       0.299243   0.042345         -0.013843  -0.016250
# PercentSalaryHike       -0.033137   0.032533          0.038125  -0.040531
# StandardHours                 NaN        NaN               NaN        NaN
# StockOptionLevel        -0.031753  -0.006839          0.011169   0.001261
# ...

# %% [markdown]
# Correlation Between Attrition and EmployeeID

# %%
stats,p=pearsonr(dataset.Attrition,dataset.EmployeeID)
print(stats,p)
# Out:
# -0.004729122995066088 0.753548740189224

# %% [raw]
# r_value=-0.004 and p_value is 0.75

# %% [raw]
# Correlation:Negative Correlation
# p_value>0.05,so H0 is Accepted

# %%
dataset.corr()
# Out:
#                               Age  Attrition  DistanceFromHome  Education  \
# Age                      1.000000  -0.159205          0.006963  -0.035706
# Attrition               -0.159205   1.000000         -0.009730  -0.015111
# DistanceFromHome         0.006963  -0.009730          1.000000  -0.008638
# Education               -0.035706  -0.015111         -0.008638   1.000000
# EmployeeCount                 NaN        NaN               NaN        NaN
# EmployeeID               0.008649  -0.004729         -0.001097  -0.009680
# JobLevel                -0.002884  -0.010290         -0.037329   0.045746
# MonthlyIncome           -0.044314  -0.031176         -0.021607   0.006410
# NumCompaniesWorked       0.299243   0.042345         -0.013843  -0.016250
# PercentSalaryHike       -0.033137   0.032533          0.038125  -0.040531
# StandardHours                 NaN        NaN               NaN        NaN
# StockOptionLevel        -0.031753  -0.006839          0.011169   0.001261
# ...

# %% [markdown]
# Correlation Between Attrition and JobLevel

# %%
stats,p=pearsonr(dataset.Attrition,dataset.JobLevel)
print(stats,p)
# Out:
# -0.01028971328749503 0.4945171727200731

# %% [raw]
# r_value=-0.01 and p_value is 0.49
# Correlation:Negative Correlation
# p_value>0.05,so H0 is Accepted

# %%
dataset.corr()
# Out:
#                               Age  Attrition  DistanceFromHome  Education  \
# Age                      1.000000  -0.159205          0.006963  -0.035706
# Attrition               -0.159205   1.000000         -0.009730  -0.015111
# DistanceFromHome         0.006963  -0.009730          1.000000  -0.008638
# Education               -0.035706  -0.015111         -0.008638   1.000000
# EmployeeCount                 NaN        NaN               NaN        NaN
# EmployeeID               0.008649  -0.004729         -0.001097  -0.009680
# JobLevel                -0.002884  -0.010290         -0.037329   0.045746
# MonthlyIncome           -0.044314  -0.031176         -0.021607   0.006410
# NumCompaniesWorked       0.299243   0.042345         -0.013843  -0.016250
# PercentSalaryHike       -0.033137   0.032533          0.038125  -0.040531
# StandardHours                 NaN        NaN               NaN        NaN
# StockOptionLevel        -0.031753  -0.006839          0.011169   0.001261
# ...

# %% [markdown]
# Correlation Between Attrition and PercentSalaryHike

# %%
stats,p=pearsonr(dataset.Attrition,dataset.PercentSalaryHike)
print(stats,p)
# Out:
# 0.032532594891053514 0.030743386433316814

# %% [raw]
# r_value=0.0325 and p_value is 0.03
# Correlation:Positive Correlation
# p_value<0.05,so H0 is Rejected

# %%
dataset.corr()
# Out:
#                               Age  Attrition  DistanceFromHome  Education  \
# Age                      1.000000  -0.159205          0.006963  -0.035706
# Attrition               -0.159205   1.000000         -0.009730  -0.015111
# DistanceFromHome         0.006963  -0.009730          1.000000  -0.008638
# Education               -0.035706  -0.015111         -0.008638   1.000000
# EmployeeCount                 NaN        NaN               NaN        NaN
# EmployeeID               0.008649  -0.004729         -0.001097  -0.009680
# JobLevel                -0.002884  -0.010290         -0.037329   0.045746
# MonthlyIncome           -0.044314  -0.031176         -0.021607   0.006410
# NumCompaniesWorked       0.299243   0.042345         -0.013843  -0.016250
# PercentSalaryHike       -0.033137   0.032533          0.038125  -0.040531
# StandardHours                 NaN        NaN               NaN        NaN
# StockOptionLevel        -0.031753  -0.006839          0.011169   0.001261
# ...

# %% [markdown]
# Correlation Between Attrition and StockOptionLevel

# %%
stats,p=pearsonr(dataset.Attrition,dataset.StockOptionLevel)
print(stats,p)
# Out:
# -0.006838852403261549 0.6498072937492487

# %% [raw]
# r_value=-0.006 and p_value is 0.64
# Correlation:Negative Correlation
# p_value>0.05,so H0 is Accepted

# %%
dataset.corr()
# Out:
#                               Age  Attrition  DistanceFromHome  Education  \
# Age                      1.000000  -0.159205          0.006963  -0.035706
# Attrition               -0.159205   1.000000         -0.009730  -0.015111
# DistanceFromHome         0.006963  -0.009730          1.000000  -0.008638
# Education               -0.035706  -0.015111         -0.008638   1.000000
# EmployeeCount                 NaN        NaN               NaN        NaN
# EmployeeID               0.008649  -0.004729         -0.001097  -0.009680
# JobLevel                -0.002884  -0.010290         -0.037329   0.045746
# MonthlyIncome           -0.044314  -0.031176         -0.021607   0.006410
# NumCompaniesWorked       0.299243   0.042345         -0.013843  -0.016250
# PercentSalaryHike       -0.033137   0.032533          0.038125  -0.040531
# StandardHours                 NaN        NaN               NaN        NaN
# StockOptionLevel        -0.031753  -0.006839          0.011169   0.001261
# ...

# %%
Correlation Between Attrition and TotalWorkingYears

# %%
stats,p=pearsonr(dataset.Attrition,dataset.TotalWorkingYears)
print(stats,p)
# Out:
# nan 1.0

# %% [markdown]
# Correlation Between Attrition and TrainingTimesLastYear

# %%
stats,p=pearsonr(dataset.Attrition,dataset.TrainingTimesLastYear)
print(stats,p)
# Out:
# -0.04943057624425504 0.0010247061915349563

# %% [raw]
# r_value=-0.04 and p_value is 0.001
# Correlation:Negative Correlation
# p_value<0.05,so H0 is Rejected

# %%
dataset.corr()
# Out:
#                               Age  Attrition  DistanceFromHome  Education  \
# Age                      1.000000  -0.159205          0.006963  -0.035706
# Attrition               -0.159205   1.000000         -0.009730  -0.015111
# DistanceFromHome         0.006963  -0.009730          1.000000  -0.008638
# Education               -0.035706  -0.015111         -0.008638   1.000000
# EmployeeCount                 NaN        NaN               NaN        NaN
# EmployeeID               0.008649  -0.004729         -0.001097  -0.009680
# JobLevel                -0.002884  -0.010290         -0.037329   0.045746
# MonthlyIncome           -0.044314  -0.031176         -0.021607   0.006410
# NumCompaniesWorked       0.299243   0.042345         -0.013843  -0.016250
# PercentSalaryHike       -0.033137   0.032533          0.038125  -0.040531
# StandardHours                 NaN        NaN               NaN        NaN
# StockOptionLevel        -0.031753  -0.006839          0.011169   0.001261
# ...

# %% [markdown]
# Correlation Between Attrition and YearsAtCompany

# %%
stats,p=pearsonr(dataset.Attrition,dataset.YearsAtCompany)
print(stats,p)
# Out:
# -0.13439221398997717 3.16388312248436e-19

# %%
3.16388312248436e-02
# Out:
# 0.0316388312248436

# %% [raw]
# r_value=-0.13 and p_value is 0.03
# Correlation:Negative Correlation
# p_value<0.05,so H0 is Rejected

# %%
dataset.corr()
# Out:
#                               Age  Attrition  DistanceFromHome  Education  \
# Age                      1.000000  -0.159205          0.006963  -0.035706
# Attrition               -0.159205   1.000000         -0.009730  -0.015111
# DistanceFromHome         0.006963  -0.009730          1.000000  -0.008638
# Education               -0.035706  -0.015111         -0.008638   1.000000
# EmployeeCount                 NaN        NaN               NaN        NaN
# EmployeeID               0.008649  -0.004729         -0.001097  -0.009680
# JobLevel                -0.002884  -0.010290         -0.037329   0.045746
# MonthlyIncome           -0.044314  -0.031176         -0.021607   0.006410
# NumCompaniesWorked       0.299243   0.042345         -0.013843  -0.016250
# PercentSalaryHike       -0.033137   0.032533          0.038125  -0.040531
# StandardHours                 NaN        NaN               NaN        NaN
# StockOptionLevel        -0.031753  -0.006839          0.011169   0.001261
# ...

# %% [markdown]
# Correlation Between Attrition and YearsAtCompany

# %%
stats,p=pearsonr(dataset.Attrition,dataset.YearsSinceLastPromotion)
print(stats,p)
# Out:
# -0.03301877514258439 0.02833033618936241

# %% [raw]
# r_value=-0.033 and p_value is 0.028
# Correlation:Negative Correlation
# p_value<0.05,so H0 is Rejected

# %%
dataset.corr()
# Out:
#                               Age  Attrition  DistanceFromHome  Education  \
# Age                      1.000000  -0.159205          0.006963  -0.035706
# Attrition               -0.159205   1.000000         -0.009730  -0.015111
# DistanceFromHome         0.006963  -0.009730          1.000000  -0.008638
# Education               -0.035706  -0.015111         -0.008638   1.000000
# EmployeeCount                 NaN        NaN               NaN        NaN
# EmployeeID               0.008649  -0.004729         -0.001097  -0.009680
# JobLevel                -0.002884  -0.010290         -0.037329   0.045746
# MonthlyIncome           -0.044314  -0.031176         -0.021607   0.006410
# NumCompaniesWorked       0.299243   0.042345         -0.013843  -0.016250
# PercentSalaryHike       -0.033137   0.032533          0.038125  -0.040531
# StandardHours                 NaN        NaN               NaN        NaN
# StockOptionLevel        -0.031753  -0.006839          0.011169   0.001261
# ...

# %% [markdown]
# Correlation Between Attrition and YearsWithCurrManager

# %%
stats,p=pearsonr(dataset.Attrition,dataset.YearsWithCurrManager)
print(stats,p)
# Out:
# -0.15619931590162842 1.7339322652874626e-25

# %%
1.7339322652874626e-2
# Out:
# 0.017339322652874627

# %% [raw]
# r_value=-0.15 and p_value is 0.017
# Correlation:Negative Correlation
# p_value<0.05,so H0 is Rejected

# %%
dataset.corr()
# Out:
#                               Age  Attrition  DistanceFromHome  Education  \
# Age                      1.000000  -0.159205          0.006963  -0.035706
# Attrition               -0.159205   1.000000         -0.009730  -0.015111
# DistanceFromHome         0.006963  -0.009730          1.000000  -0.008638
# Education               -0.035706  -0.015111         -0.008638   1.000000
# EmployeeCount                 NaN        NaN               NaN        NaN
# EmployeeID               0.008649  -0.004729         -0.001097  -0.009680
# JobLevel                -0.002884  -0.010290         -0.037329   0.045746
# MonthlyIncome           -0.044314  -0.031176         -0.021607   0.006410
# NumCompaniesWorked       0.299243   0.042345         -0.013843  -0.016250
# PercentSalaryHike       -0.033137   0.032533          0.038125  -0.040531
# StandardHours                 NaN        NaN               NaN        NaN
# StockOptionLevel        -0.031753  -0.006839          0.011169   0.001261
# ...
